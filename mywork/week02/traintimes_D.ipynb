# %%
from xml.dom.minidom import parseString
import requests
import csv

# Define the tags you want to retrieve from the XML
retrieveTags = [
    'TrainStatus',
    'TrainLatitude',
    'TrainLongitude',
    'TrainCode',
    'TrainDate',
    'PublicMessage',
    'Direction'
]

# URL for the Irish Rail API
url = "http://api.irishrail.ie/realtime/realtime.asmx/getCurrentTrainsXML"
page = requests.get(url)

# Parse the XML content using minidom
doc = parseString(page.content)

# Check if it works, output the formatted XML to the console
# This step is optional; you can remove it once you confirm the data is correct
print(doc.toprettyxml(newl=''))

# Save the raw XML to a file (optional)
with open("trainxml.xml", "w") as xmlfp:
    doc.writexml(xmlfp)

# Open a CSV file to store the filtered data
with open('traintimes_D.csv', mode='w', newline='') as train_file:
    train_writer = csv.writer(train_file, delimiter='\t', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    # Write the header row to the CSV
    train_writer.writerow(retrieveTags)

    # Get the train positions from the XML
    objTrainPositionsNodes = doc.getElementsByTagName("objTrainPositions")
    
    # Loop through each train position in the XML
    for objTrainPositionsNode in objTrainPositionsNodes:
        # Extract the TrainCode (this is what we will filter on)
        traincodenode = objTrainPositionsNode.getElementsByTagName("TrainCode").item(0)
        traincode = traincodenode.firstChild.nodeValue.strip()
        
        # Only process trains whose TrainCode starts with "D"
        if traincode.startswith("D"):
            dataList = []
            
            # Retrieve all the tags and their values for this train
            for retrieveTag in retrieveTags:
                datanode = objTrainPositionsNode.getElementsByTagName(retrieveTag).item(0)
                dataList.append(datanode.firstChild.nodeValue.strip())

            # Write the filtered train data to the CSV file
            train_writer.writerow(dataList)
# Out:
# <?xml version="1.0" ?><ArrayOfObjTrainPositions xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns="http://api.irishrail.ie/realtime/">
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>51.8491</TrainLatitude>
#     		<TrainLongitude>-8.29956</TrainLongitude>
#     		<TrainCode>P532</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P532\nCobh to Cork\nExpected Departure 18:30</PublicMessage>
#     		<Direction>To Cork</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>51.9018</TrainLatitude>
#     		<TrainLongitude>-8.4582</TrainLongitude>
#     		<TrainCode>D532</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D532\nCork to Cobh\nExpected Departure 18:30</PublicMessage>
#     		<Direction>To Cobh</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>51.9018</TrainLatitude>
#     		<TrainLongitude>-8.4582</TrainLongitude>
#     		<TrainCode>D576</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D576\nCork to Midleton\nExpected Departure 18:45</PublicMessage>
#     		<Direction>To Midleton</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>51.9212</TrainLatitude>
#     		<TrainLongitude>-8.17579</TrainLongitude>
#     		<TrainCode>P575</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P575\nMidleton to Cork\nExpected Departure 18:45</PublicMessage>
#     		<Direction>To Cork</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>52.5009</TrainLatitude>
#     		<TrainLongitude>-8.20003</TrainLongitude>
#     		<TrainCode>A576</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A576\nLimerick Junction to Waterford\nExpected Departure 18:40</PublicMessage>
#     		<Direction>To Waterford</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>53.1442</TrainLatitude>
#     		<TrainLongitude>-6.06085</TrainLongitude>
#     		<TrainCode>E839</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E839\nGreystones to Malahide\nExpected Departure 18:31</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>53.3397</TrainLatitude>
#     		<TrainLongitude>-6.23773</TrainLongitude>
#     		<TrainCode>D420</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D420\nGrand Canal Dock to Hazelhatch\nExpected Departure 18:40</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>53.3531</TrainLatitude>
#     		<TrainLongitude>-6.24591</TrainLongitude>
#     		<TrainCode>A614</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A614\nDublin Connolly to Wexford\nExpected Departure 18:28</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>53.3531</TrainLatitude>
#     		<TrainLongitude>-6.24591</TrainLongitude>
#     		<TrainCode>D931</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D931\nDublin Connolly to Maynooth\nExpected Departure 18:45</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>53.378</TrainLatitude>
#     		<TrainLongitude>-6.58993</TrainLongitude>
#     		<TrainCode>P764</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P764\nMaynooth to Dublin Connolly\nExpected Departure 18:41</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>53.3891</TrainLatitude>
#     		<TrainLongitude>-6.07401</TrainLongitude>
#     		<TrainCode>E252</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E252\nHowth to Bray\nExpected Departure 18:35</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>53.4349</TrainLatitude>
#     		<TrainLongitude>-6.46898</TrainLongitude>
#     		<TrainCode>P325</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P325\nM3 Parkway to Docklands\nExpected Departure 18:40</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>N</TrainStatus>
#     		<TrainLatitude>53.4509</TrainLatitude>
#     		<TrainLongitude>-6.15649</TrainLongitude>
#     		<TrainCode>E253</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E253\nMalahide to Bray\nExpected Departure 18:44</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>0</TrainLatitude>
#     		<TrainLongitude>0</TrainLongitude>
#     		<TrainCode>A220</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A220\n16:00 - Dublin Heuston to Cork (5 mins late)\nDeparted Killarney Junction next stop Cork</PublicMessage>
#     		<Direction>To Cork</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>0</TrainLatitude>
#     		<TrainLongitude>0</TrainLongitude>
#     		<TrainCode>A222</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A222\n17:00 - Dublin Heuston to Cork (-2 mins late)\nArrived LJ896 next stop Mallow</PublicMessage>
#     		<Direction>To Cork</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>0</TrainLatitude>
#     		<TrainLongitude>0</TrainLongitude>
#     		<TrainCode>A225</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A225\n17:25 - Cork to Dublin Heuston (6 mins late)\nDeparted LJ461 next stop Thurles</PublicMessage>
#     		<Direction>To Dublin Heuston</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>0</TrainLatitude>
#     		<TrainLongitude>0</TrainLongitude>
#     		<TrainCode>A312</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A312\n17:05 - Dublin Heuston to Tralee (-1 mins late)\nArrived LJ458 next stop Charleville</PublicMessage>
#     		<Direction>To Tralee</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>0</TrainLatitude>
#     		<TrainLongitude>0</TrainLongitude>
#     		<TrainCode>A526</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A526\n18:35 - Dublin Heuston to Waterford (-3 mins late)\nArrived Inchicore Advance Starter next stop Newbridge</PublicMessage>
#     		<Direction>To Waterford</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>0</TrainLatitude>
#     		<TrainLongitude>0</TrainLongitude>
#     		<TrainCode>A726</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A726\n18:30 - Dublin Heuston to Galway (0 mins late)\nDeparted Inchicore Advance Starter next stop Monasterevin</PublicMessage>
#     		<Direction>To Galway</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>0</TrainLatitude>
#     		<TrainLongitude>0</TrainLongitude>
#     		<TrainCode>D533</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D533\n18:25 - Mallow to Cork (1 mins late)\nDeparted Killarney Junction next stop Cork</PublicMessage>
#     		<Direction>To Cork</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>0</TrainLatitude>
#     		<TrainLongitude>0</TrainLongitude>
#     		<TrainCode>P762</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P762\n17:51 - Maynooth to Dublin Connolly (2 mins late)\nDeparted North Strand Junction next stop Dublin Connolly</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>52.1396</TrainLatitude>
#     		<TrainLongitude>-8.65521</TrainLongitude>
#     		<TrainCode>A310</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A310\n17:25 - Mallow to Tralee (3 mins late)\nDeparted Mallow next stop Banteer</PublicMessage>
#     		<Direction>To Tralee</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>52.5009</TrainLatitude>
#     		<TrainLongitude>-8.20003</TrainLongitude>
#     		<TrainCode>A444</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A444\n18:32 - Limerick Junction to Limerick (4 mins late)\nDeparted Limerick Junction next stop Limerick</PublicMessage>
#     		<Direction>To Limerick</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>52.8999</TrainLatitude>
#     		<TrainLongitude>-7.60259</TrainLongitude>
#     		<TrainCode>A412</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A412\n17:25 - Dublin Heuston to Limerick (0 mins late)\nDeparted Ballybrophy next stop Templemore</PublicMessage>
#     		<Direction>To Limerick</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>52.992</TrainLatitude>
#     		<TrainLongitude>-6.9762</TrainLongitude>
#     		<TrainCode>A522</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A522\n16:40 - Dublin Heuston to Waterford (3 mins late)\nDeparted Athy next stop Carlow</PublicMessage>
#     		<Direction>To Waterford</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>52.992</TrainLatitude>
#     		<TrainLongitude>-6.9762</TrainLongitude>
#     		<TrainCode>A524</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A524\n17:35 - Dublin Heuston to Waterford (14 mins late)\nArrived Athy next stop Carlow</PublicMessage>
#     		<Direction>To Waterford</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.0371</TrainLatitude>
#     		<TrainLongitude>-7.30086</TrainLongitude>
#     		<TrainCode>P224</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P224\n18:29 - Portlaoise to Dublin Heuston (0 mins late)\nDeparted Portlaoise next stop Portarlington</PublicMessage>
#     		<Direction>To Dublin Heuston</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.1442</TrainLatitude>
#     		<TrainLongitude>-6.06085</TrainLongitude>
#     		<TrainCode>A610</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A610\n16:28 - Dublin Connolly to Rosslare Europort (25 mins late)\nDeparted Greystones next stop Kilcoole</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.1454</TrainLatitude>
#     		<TrainLongitude>-7.06361</TrainLongitude>
#     		<TrainCode>D218</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D218\n17:27 - Dublin Heuston to Portlaoise (11 mins late)\nDeparted Monasterevin next stop Portarlington</PublicMessage>
#     		<Direction>To Portlaoise</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.1545</TrainLatitude>
#     		<TrainLongitude>-6.96542</TrainLongitude>
#     		<TrainCode>A224</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A224\n18:00 - Dublin Heuston to Cork (8 mins late)\nDeparted Cherryville Junction next stop Ballybrophy</PublicMessage>
#     		<Direction>To Cork</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.163</TrainLatitude>
#     		<TrainLongitude>-6.90802</TrainLongitude>
#     		<TrainCode>A223</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A223\n16:25 - Cork to Dublin Heuston (-2 mins late)\nDeparted Kildare next stop Dublin Heuston</PublicMessage>
#     		<Direction>To Dublin Heuston</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.2043</TrainLatitude>
#     		<TrainLongitude>-6.10046</TrainLongitude>
#     		<TrainCode>E941</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E941\n18:35 - Bray to Howth (1 mins late)\nDeparted Bray next stop Shankill</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.2135</TrainLatitude>
#     		<TrainLongitude>-7.35205</TrainLongitude>
#     		<TrainCode>A724</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A724\n17:30 - Dublin Heuston to Galway (12 mins late)\nDeparted Geashill next stop Tullamore</PublicMessage>
#     		<Direction>To Galway</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.2469</TrainLatitude>
#     		<TrainLongitude>-6.66386</TrainLongitude>
#     		<TrainCode>A808</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A808\n18:15 - Dublin Heuston to Westport (2 mins late)\nDeparted Sallins next stop Tullamore</PublicMessage>
#     		<Direction>To Westport</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.2469</TrainLatitude>
#     		<TrainLongitude>-6.66386</TrainLongitude>
#     		<TrainCode>D417</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D417\n17:29 - Grand Canal Dock to Newbridge (2 mins late)\nDeparted Sallins next stop Newbridge</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.2557</TrainLatitude>
#     		<TrainLongitude>-6.11317</TrainLongitude>
#     		<TrainCode>E838</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E838\n18:25 - Bray to Malahide (2 mins late)\nDeparted Killiney next stop Dalkey</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.2756</TrainLatitude>
#     		<TrainLongitude>-6.10333</TrainLongitude>
#     		<TrainCode>E124</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E124\n17:24 - Malahide to Greystones (9 mins late)\nDeparted Dalkey next stop Killiney</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.2812</TrainLatitude>
#     		<TrainLongitude>-6.12289</TrainLongitude>
#     		<TrainCode>E248</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E248\n17:35 - Howth to Bray (2 mins late)\nArrived Glenageary next stop Dalkey</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.2954</TrainLatitude>
#     		<TrainLongitude>-6.15206</TrainLongitude>
#     		<TrainCode>E940</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E940\n18:01 - Greystones to Howth (0 mins late)\nArrived Salthill and Monkstown next stop Seapoint</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3206</TrainLatitude>
#     		<TrainLongitude>-6.21112</TrainLongitude>
#     		<TrainCode>E249</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E249\n17:44 - Malahide to Bray (9 mins late)\nDeparted Sydney Parade next stop Booterstown</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3206</TrainLatitude>
#     		<TrainLongitude>-6.21112</TrainLongitude>
#     		<TrainCode>E837</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E837\n18:05 - Bray to Malahide (0 mins late)\nArrived Sydney Parade next stop Sandymount</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3212</TrainLatitude>
#     		<TrainLongitude>-8.60608</TrainLongitude>
#     		<TrainCode>A720</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A720\n16:30 - Dublin Heuston to Galway (6 mins late)\nArrived Attymon next stop Athenry</PublicMessage>
#     		<Direction>To Galway</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3223</TrainLatitude>
#     		<TrainLongitude>-6.52356</TrainLongitude>
#     		<TrainCode>D219</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D219\n18:05 - Dublin Heuston to Portlaoise (0 mins late)\nDeparted Hazelhatch next stop Sallins</PublicMessage>
#     		<Direction>To Portlaoise</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3334</TrainLatitude>
#     		<TrainLongitude>-6.40628</TrainLongitude>
#     		<TrainCode>A227</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A227\n18:25 - Cork to Dublin Heuston (9 mins late)\nDeparted Clondalkin next stop Dublin Heuston</PublicMessage>
#     		<Direction>To Dublin Heuston</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3334</TrainLatitude>
#     		<TrainLongitude>-6.40628</TrainLongitude>
#     		<TrainCode>A231</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A231\n20:25 - Cork to Dublin Heuston (9 mins late)\nDeparted Clondalkin next stop Dublin Heuston</PublicMessage>
#     		<Direction>To Dublin Heuston</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3334</TrainLatitude>
#     		<TrainLongitude>-6.40628</TrainLongitude>
#     		<TrainCode>D418</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D418\n18:10 - Dublin Connolly to Hazelhatch (0 mins late)\nDeparted Clondalkin next stop Kishoge</PublicMessage>
#     		<Direction>To Hazelhatch</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.334</TrainLatitude>
#     		<TrainLongitude>-6.37868</TrainLongitude>
#     		<TrainCode>D220</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D220\n18:25 - Dublin Heuston to Portlaoise (0 mins late)\nArrived Park West and Cherry Orchard next stop Clondalkin</PublicMessage>
#     		<Direction>To Portlaoise</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.334</TrainLatitude>
#     		<TrainLongitude>-6.37868</TrainLongitude>
#     		<TrainCode>P223</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P223\n17:25 - Portlaoise to Dublin Heuston (0 mins late)\nDeparted Park West and Cherry Orchard next stop Dublin Heuston</PublicMessage>
#     		<Direction>To Dublin Heuston</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3345</TrainLatitude>
#     		<TrainLongitude>-6.43038</TrainLongitude>
#     		<TrainCode>P418</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P418\n18:13 - Newbridge to Grand Canal Dock (3 mins late)\nDeparted Kishoge next stop Park West and Cherry Orchard</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3347</TrainLatitude>
#     		<TrainLongitude>-6.22979</TrainLongitude>
#     		<TrainCode>E125</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E125\n17:55 - Howth to Greystones (4 mins late)\nArrived Lansdowne Road next stop Sandymount</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3347</TrainLatitude>
#     		<TrainLongitude>-6.22979</TrainLongitude>
#     		<TrainCode>E939</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E939\n17:55 - Bray to Howth (5 mins late)\nDeparted Lansdowne Road next stop Grand Canal Dock</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3395</TrainLatitude>
#     		<TrainLongitude>-7.61596</TrainLongitude>
#     		<TrainCode>A722</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A722\n17:10 - Dublin Heuston to Athlone (9 mins late)\nDeparted Clara next stop Athlone</PublicMessage>
#     		<Direction>To Athlone</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3433</TrainLatitude>
#     		<TrainLongitude>-6.24829</TrainLongitude>
#     		<TrainCode>P417</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P417\n17:53 - Hazelhatch to Grand Canal Dock (6 mins late)\nArrived Dublin Pearse next stop Grand Canal Dock</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.347</TrainLatitude>
#     		<TrainLongitude>-6.25425</TrainLongitude>
#     		<TrainCode>E836</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E836\n17:31 - Greystones to Malahide (6 mins late)\nDeparted Tara Street next stop Dublin Connolly</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3509</TrainLatitude>
#     		<TrainLongitude>-6.23929</TrainLongitude>
#     		<TrainCode>D323</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D323\n18:27 - Docklands to M3 Parkway (7 mins late)\nDeparted Docklands next stop Broombridge</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3531</TrainLatitude>
#     		<TrainLongitude>-6.24591</TrainLongitude>
#     		<TrainCode>E250</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E250\n18:04 - Malahide to Bray (4 mins late)\nDeparted Dublin Connolly next stop Tara Street</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3531</TrainLatitude>
#     		<TrainLongitude>-6.24591</TrainLongitude>
#     		<TrainCode>E938</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E938\n17:35 - Bray to Howth (13 mins late)\nArrived Dublin Connolly next stop Clontarf Road</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3629</TrainLatitude>
#     		<TrainLongitude>-6.22753</TrainLongitude>
#     		<TrainCode>A121</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A121\n16:00 - Belfast to Dublin Connolly (24 mins late)\nDeparted Clontarf Road next stop Dublin Connolly</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3632</TrainLatitude>
#     		<TrainLongitude>-6.25908</TrainLongitude>
#     		<TrainCode>A911</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A911\n15:05 - Sligo to Dublin Connolly (23 mins late)\nArrived Drumcondra next stop Dublin Connolly</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3632</TrainLatitude>
#     		<TrainLongitude>-6.25908</TrainLongitude>
#     		<TrainCode>D929</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D929\n17:30 - Bray to Maynooth (8 mins late)\nDeparted Drumcondra next stop Broombridge</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3704</TrainLatitude>
#     		<TrainLongitude>-6.50598</TrainLongitude>
#     		<TrainCode>P763</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P763\n18:22 - Maynooth to Dublin Connolly (5 mins late)\nArrived Leixlip (Louisa Bridge) next stop Leixlip (Confey)</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.373</TrainLatitude>
#     		<TrainLongitude>-6.20442</TrainLongitude>
#     		<TrainCode>E251</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E251\n18:15 - Howth to Bray (4 mins late)\nDeparted Killester next stop Clontarf Road</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3743</TrainLatitude>
#     		<TrainLongitude>-6.48624</TrainLongitude>
#     		<TrainCode>D928</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D928\n18:00 - Dublin Connolly to Maynooth (3 mins late)\nArrived Leixlip (Confey) next stop Leixlip (Louisa Bridge)</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3776</TrainLatitude>
#     		<TrainLongitude>-6.39072</TrainLongitude>
#     		<TrainCode>P324</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P324\n18:10 - M3 Parkway to Docklands (10 mins late)\nDeparted Coolmine next stop Castleknock</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3816</TrainLatitude>
#     		<TrainLongitude>-6.37149</TrainLongitude>
#     		<TrainCode>D930</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D930\n18:16 - Dublin Connolly to Longford (6 mins late)\nArrived Castleknock next stop Maynooth</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3909</TrainLatitude>
#     		<TrainLongitude>-6.15672</TrainLongitude>
#     		<TrainCode>E835</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E835\n17:25 - Bray to Malahide (9 mins late)\nArrived Howth Junction next stop Clongriffin</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.3917</TrainLatitude>
#     		<TrainLongitude>-6.13678</TrainLongitude>
#     		<TrainCode>E937</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E937\n17:01 - Greystones to Howth (15 mins late)\nDeparted Bayside next stop Sutton</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.4157</TrainLatitude>
#     		<TrainLongitude>-6.83395</TrainLongitude>
#     		<TrainCode>D925</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D925\n17:09 - Grand Canal Dock to Longford (10 mins late)\nDeparted Enfield next stop Mullingar</PublicMessage>
#     		<Direction>To Longford</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.4169</TrainLatitude>
#     		<TrainLongitude>-6.1512</TrainLongitude>
#     		<TrainCode>E126</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E126\n18:25 - Malahide to Greystones (6 mins late)\nDeparted Portmarnock next stop Clongriffin</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.4175</TrainLatitude>
#     		<TrainLongitude>-6.46483</TrainLongitude>
#     		<TrainCode>D322</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D322\n17:55 - Docklands to M3 Parkway (8 mins late)\nDeparted Dunboyne next stop M3 Parkway</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.4273</TrainLatitude>
#     		<TrainLongitude>-7.93683</TrainLongitude>
#     		<TrainCode>A725</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A725\n17:20 - Galway to Dublin Heuston (7 mins late)\nArrived Athlone next stop Tullamore</PublicMessage>
#     		<Direction>To Dublin Heuston</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.4509</TrainLatitude>
#     		<TrainLongitude>-6.15649</TrainLongitude>
#     		<TrainCode>D828</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D828\n17:59 - Grand Canal Dock to Dundalk (4 mins late)\nDeparted Malahide next stop Donabate</PublicMessage>
#     		<Direction>To Dundalk</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.4855</TrainLatitude>
#     		<TrainLongitude>-6.15134</TrainLongitude>
#     		<TrainCode>P619</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P619\n17:43 - Drogheda to Grand Canal Dock (19 mins late)\nArrived Donabate next stop Malahide</PublicMessage>
#     		<Direction>To Grand Canal Dock</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.4933</TrainLatitude>
#     		<TrainLongitude>-7.15576</TrainLongitude>
#     		<TrainCode>A912</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A912\n17:05 - Dublin Connolly to Sligo (14 mins late)\nDeparted Killucan next stop Mullingar</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.5201</TrainLatitude>
#     		<TrainLongitude>-6.1439</TrainLongitude>
#     		<TrainCode>P712</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P712\n17:59 - Drogheda to Dublin Connolly (12 mins late)\nArrived Rush and Lusk next stop Malahide</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.6118</TrainLatitude>
#     		<TrainLongitude>-6.18226</TrainLongitude>
#     		<TrainCode>D827</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D827\n17:53 - Dublin Connolly to Drogheda (1 mins late)\nArrived Balbriggan next stop Gormanston</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.6118</TrainLatitude>
#     		<TrainLongitude>-6.18226</TrainLongitude>
#     		<TrainCode>P620</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P620\n18:03 - Drogheda to Grand Canal Dock (12 mins late)\nDeparted Balbriggan next stop Skerries</PublicMessage>
#     		<Direction>To Grand Canal Dock</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.6794</TrainLatitude>
#     		<TrainLongitude>-6.24253</TrainLongitude>
#     		<TrainCode>A124</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A124\n17:50 - Dublin Connolly to Belfast (13 mins late)\nDeparted Laytown next stop Drogheda</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.6794</TrainLatitude>
#     		<TrainLongitude>-6.24253</TrainLongitude>
#     		<TrainCode>D826</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D826\n16:40 - Bray to Drogheda (14 mins late)\nDeparted Laytown next stop Drogheda</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.6888</TrainLatitude>
#     		<TrainLongitude>-7.60299</TrainLongitude>
#     		<TrainCode>A913</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A913\n17:05 - Sligo to Dublin Connolly (1 mins late)\nArrived Edgeworthstown next stop Mullingar</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.712</TrainLatitude>
#     		<TrainLongitude>-6.33538</TrainLongitude>
#     		<TrainCode>D825</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D825\n16:40 - Dun Laoghaire to Dundalk (5 mins late)\nDeparted Drogheda next stop Dundalk</PublicMessage>
#     		<Direction>To Dundalk</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>53.8591</TrainLatitude>
#     		<TrainLongitude>-7.9164</TrainLongitude>
#     		<TrainCode>A910</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A910\n16:02 - Dublin Connolly to Sligo (31 mins late)\nArrived Dromod next stop Carrick on Shannon</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>54.0007</TrainLatitude>
#     		<TrainLongitude>-6.41291</TrainLongitude>
#     		<TrainCode>A120</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A120\n15:50 - Dublin Connolly to Belfast (27 mins late)\nDeparted Dundalk next stop Newry</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>54.0007</TrainLatitude>
#     		<TrainLongitude>-6.41291</TrainLongitude>
#     		<TrainCode>A122</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A122\n16:50 - Dublin Connolly to Belfast (21 mins late)\nDeparted Dundalk next stop Newry</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>54.0007</TrainLatitude>
#     		<TrainLongitude>-6.41291</TrainLongitude>
#     		<TrainCode>A123</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A123\n17:00 - Belfast to Dublin Connolly (0 mins late)\nDeparted Dundalk next stop Drogheda</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>R</TrainStatus>
#     		<TrainLatitude>54.0887</TrainLatitude>
#     		<TrainLongitude>-8.52088</TrainLongitude>
#     		<TrainCode>A908</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A908\n15:05 - Dublin Connolly to Sligo (22 mins late)\nDeparted Ballymote next stop Collooney</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>T</TrainStatus>
#     		<TrainLatitude>52.5009</TrainLatitude>
#     		<TrainLongitude>-8.20003</TrainLongitude>
#     		<TrainCode>A445</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>A445\n17:45 - Limerick to Limerick Junction(8 mins late)\nTERMINATED Limerick Junction at 18:27</PublicMessage>
#     		<Direction>To Limerick Junction</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>T</TrainStatus>
#     		<TrainLatitude>53.1442</TrainLatitude>
#     		<TrainLongitude>-6.06085</TrainLongitude>
#     		<TrainCode>E123</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E123\n16:55 - Howth to Greystones(12 mins late)\nTERMINATED Greystones at 18:34</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>T</TrainStatus>
#     		<TrainLatitude>53.2043</TrainLatitude>
#     		<TrainLongitude>-6.10046</TrainLongitude>
#     		<TrainCode>E246</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E246\n17:04 - Malahide to Bray(10 mins late)\nTERMINATED Bray at 18:28</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>T</TrainStatus>
#     		<TrainLatitude>53.2043</TrainLatitude>
#     		<TrainLongitude>-6.10046</TrainLongitude>
#     		<TrainCode>E247</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E247\n17:15 - Howth to Bray(6 mins late)\nTERMINATED Bray at 18:34</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>T</TrainStatus>
#     		<TrainLatitude>53.3509</TrainLatitude>
#     		<TrainLongitude>-6.23929</TrainLongitude>
#     		<TrainCode>P323</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>P323\n17:36 - M3 Parkway to Docklands(16 mins late)\nTERMINATED Docklands at 18:28</PublicMessage>
#     		<Direction>Southbound</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>T</TrainStatus>
#     		<TrainLatitude>53.378</TrainLatitude>
#     		<TrainLongitude>-6.58993</TrainLongitude>
#     		<TrainCode>D927</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>D927\n17:39 - Grand Canal Dock to Maynooth(0 mins late)\nTERMINATED Maynooth at 18:33</PublicMessage>
#     		<Direction>To Maynooth</Direction>
#   	</objTrainPositions>
#   	<objTrainPositions>
#     		<TrainStatus>T</TrainStatus>
#     		<TrainLatitude>53.4509</TrainLatitude>
#     		<TrainLongitude>-6.15649</TrainLongitude>
#     		<TrainCode>E834</TrainCode>
#     		<TrainDate>11 Feb 2025</TrainDate>
#     		<PublicMessage>E834\n17:05 - Bray to Malahide(10 mins late)\nTERMINATED Malahide at 18:28</PublicMessage>
#     		<Direction>Northbound</Direction>
#   	</objTrainPositions>
# </ArrayOfObjTrainPositions>
